# %% [markdown]
# **Autor:** Dagmara Lopatková
# ***
# **<font size=6 color=blueviolet> Bowling a jeho tajomstvá </font>**
#
# <font size=5> Sú výsledky hráča v priebehu hry od seba závislé? </font>
#
# ---
# <a id=table_of_contents></a>
# ###  Obsah
# * [Úvod](#úvod) - kolky alebo bowling?
# * [Bez pravidiel ani na krok!](#Bez_pravidiel_ani_na_krok!) - vieme pravidlá bowlingu? ako je to s bodmi?
# * [Zavedenie nášho problému](#Zavedenie_nášho_problému) - závislé vs. nezávislé
# * [Použité testy](#Použité_testy) - vzorový príklad
# * [Aplikácia testov na nami získané reálne dáta](#Aplikácia_testov_na_namerané_dáta) - vlastné príklady podľa reálnych dát
# * [Záver](#Záver) - zhodnotenie celej problematiky
# * [Zdroje](#Zdroje) - zoznam použitej literatúry

# %% [markdown]
# ***
# <a id=úvod></a>
# # <font color= blueviolet> Úvod </font>
#
#
# ### Kolky alebo bowling?
#
# Kolky alebo bowling? Sú to rovnaké alebo rôzne hry? Veľa ľudí si myslí, že je to jedna a tá istá hra. Čo samozrejme **nie je** pravda.
# Bowling sa od koliek líši vo viacerých aspektoch. V kolkách sa používa 9 koliek, ktoré sú usporiadané do kosoštvorca, zatiaľ čo v bowlingu je rozmiestnených **10 koliek** do tvaru trojuholníka. Ďalšou odlišnosťou je, že kolky sa hrajú s guľami rovnakej hmotnosti bez dier. V bowlingu máme **rôzne hmotnosti gúľ**, ktoré majú **tri diery** na prsty a palec. Najzákladnejším rozdielom týchto hier je maximálne získaný počet bodov. V kolkách môžeme maximálne získať 120 bodov, zatiaľ, čo v bowlingu je to až **300 bodov**.

# %% [markdown]
# ***
# <a id=Bez_pravidiel_ani_na_krok!></a>
# # <font color= blueviolet> Bez pravidiel ani na krok! </font>
#
#
# ### Vieme pravidlá bowlingu?
#
# Cieľom hráča je zhodiť vrhnutou bowlingovou guľou všetkých 10 koliek, ktoré stoja vo vzdialenosti 18,5 m rozostavané do rovnoramenného trojuholníka. Hmotnosť bowlingovej gule sa pohybuje od 3,6 do 7,2 kg. Bowling sa hrá na body a vyhráva ten, kto v hre dosiahne najvyššie bodové skóre.
# V každej hre sa hádže v desiatich kolách po dva hody. V prípade, že hráč prvým hodom zhodí všetky kolky, druhý hod v danom kole už nehrá. **Strike** nastáva pri situácií, keď prvým hodom hráč zhodí všetkých 10 koliek. Ak prvým hodom hráč **nezhodí všetkých 10**, ale druhým hodom zhodí zvyšné, tak vtedy hovoríme, že nastal **spare**. Ak zhodí všetkých 10 v poslednom kole, hráč má bonusové hody (jeden v prípade spare a dva v prípade strike).
# Bowling sa hrá na dráhe, ktorá sa člení na tri časti:
#
# **1. kĺzajúcu;**
#
#
# **2. rotujúcu;**
#
#
# **3. oblúkovú.**
#
# Poďľa pomenovaní vieme, ako sa správa bowlingová guľa na dráhe. V prvej časti, ktorá je najviac naolejovaná, guľa kĺže, v druhej sa vytvára jej rotácia v tretej, ktorá musí beť úplne suchá sa vytvára oblúk.
#
#
# ### Ako je to s bodmi?
# Pri **strike** hráč získa **10 bodov + prémiu v hodnote jeho nasledujúcich dvoch hodov**. Ak by **3-krát** po sebe získal strike, tak za prvé kolo by získal 30 bodov. **Perfektná hra sa skladá z 12 strike s maximálnym počtom 300 bodov**.
#
# Príklad:
# 1. kolo, 1.guľa:10
# 2. kolo, 1.guľa:10
# 3. kolo, 1.guľa:10
# 4. kolo, 1.guľa:3
# 4. kolo, 2.guľa:6
#
# Za prvé kolo získa **30 bodov**, za 2. **23**, za 3. **19** a za 4. **9 bodov**, spolu teda **81 bodov**.
#
# Zhodením všetkých 10 koliek dvoma hodmi, čiže nastal **spare**, vtedy hráč získa **10 bodov + prémiu za prvý hod nasledujúceho kola**.
#
# Za dobrú hru sa považuje skóre nad **200** bodov.

# %% [markdown]
# ***
# <a id=Zavedenie_nášho_problému></a>
# # <font color=blueviolet> Zavedenie nášho problému </font>
#
#
# ### Závislé vs. nezávislé
# Budeme predpokladať **strike** **(S)** za úspech a každý iný výsledok za neúspech **(N)**. Našou otázkou, záhadou je, že či výsledky hráča v priebehu hry sú na sebe nezávislé a či sa v priebehu hry nemení pravdepodobnosť úspechu.
# Úsek ronakých výsledkov, ktoré sú ohraničené zľava aj sprava iným výsledkom sa nazýva **iterácia**. Tento pojem bude pre nás v tejto časti veľmi dôležitý.

# %% [markdown]
# ***
# <a id=Použité_testy></a>
# # <font color=blueviolet> Použité testy </font>
#
#
# ### Vzorový príklad
# Na tomto príklade si ukážeme testy, ktoré použijeme neskôr na reálnych dátach.
# Máme výsledok $$N,N,S,S,N,S,S,S,S,S,N$$
#
# Použijeme:
# 1. Test založený na **kontingenčnej tabuľke**:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$\text{Tab.2.1: Kontigenčná tabuľka}$$

# %% [markdown]
# Pomocou softvéru **R** otestujeme hypotézu nezávislosti v Tab.2.1: takto:

# %%
tbl<-matrix(c(5,2,2,1), byrow=T, nrow=2)
fisher.test(tbl, alternative="greater")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  tbl
# p-value = 0.7083
# alternative hypothesis: true odds ratio is greater than 1
# 95 percent confidence interval:
#  0.02895982        Inf
# sample estimates:
# odds ratio
#   1.221835

# %% [markdown]
# Vzhľadom na to, že **p-hodnota** je rovná $0.7083$, čo je vcelku vysoké číslo, tak $H_0$ nie je možné zamietnuť. ($H_0$ predpokladá, že výsledky sú na sebe nezávislé).

# %% [markdown]
# 2. Test založený na **počte iteracií**:

# %%
library(randomizeBE)
pruns.exact(r=5,n1=7,n2=4, tail="lower")
# Out:
# [1] 0.3333333

# %% [markdown]
# Vo funkcii `pruns.exact()` je $r$ rovno počet iteracií, $n1=a$ a $n2=b$, kde platí, že $a\ge b$. Máme tu prvky dvoch typov $S$ a $N$. Početnosť jedného typu oznacíme $a$, počet druhého typu označíme $b$.
# Tu je **p-hodnota** vypočítaná presne.

# %% [markdown]
# 3. **Asymptotický** test:

# %%
library(tseries)
x<-factor(c("N","N","S","S","N","S","S","S","S","S","N"))
runs.test(x, alternative="less")
# Out:
# 	Runs Test
#
# data:  x
# Standard Normal = -0.75593, p-value = 0.2248
# alternative hypothesis: less

# %% [markdown]
# Pri malej dĺžke postupnosti je výraznejší rozdiel medzi **presnou p-hodnotou** a **asymptotickou p-hodnotou**. Hoci sa p-hodnoty aplikovaných testov nerovnajú, no všetky testy vedú k **nezamietnutiu $H_0$**. Ak by p-hodnota vyšla menšia ako hladina významnosti testu $\alpha$ (štandardne $\alpha=0.95$), tak by sme mohli zamietnuť $H_0$ a prijať alternatívnu hypotézu $H_1$, ktorá hovorí o závislosti výsledkov hráča v priebehu hry.

# %% [markdown]
# ***
# <a id=Aplikácia_testov_na_namerané_dáta></a>
# # <font color=blueviolet> Aplikácia testov na nami získané reálne dáta </font>
#
#
# ### 1.PRÍKLAD
# Začneme od najmenšieho bodového zisku.
# Máme výsledok $$N,N,N,N,N,S,S,N,S,N,N,N$$

# %% [markdown]
# ![305942160_1760243621004117_1993918672833771445_n.jpg](attachment:305942160_1760243621004117_1993918672833771445_n.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$\text{Tab.2.2: Kontigenčná tabuľka}$$

# %%
#1.spôsob
library(tseries)
x<-factor(c("N","N","N","N","N","S","S","N","S","N","N","N"))
runs.test(x,alternative="less")
# Out:
# 	Runs Test
#
# data:  x
# Standard Normal = -0.41786, p-value = 0.338
# alternative hypothesis: less

# %%
#2.spôsob
library(randomizeBE)
pruns.exact(r=5,n1=9,n2=3,tail = "lower")
# Out:
# [1] 0.4909091

# %%
#3.spôsob
#prvý riadok - prvý stĺpec, prvý riadok - druhý stĺpec
tbl<-matrix(c(1,2,2,6),byrow=T, nrow=2)
fisher.test(tbl,alternative = "greater")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  tbl
# p-value = 0.6606
# alternative hypothesis: true odds ratio is greater than 1
# 95 percent confidence interval:
#  0.03474235        Inf
# sample estimates:
# odds ratio
#   1.443222

# %% [markdown]
# Ako môžeme vidieť $p$-hodnota je väčšia ako hladina $\alpha$, preto nemôžeme zamietnuť $H_0$.

# %% [markdown]
# ### 2.PRÍKLAD
# Máme výsledok $$S,N,N,N,N,S,N,S,S,S,N,N$$

# %% [markdown]
# ![305999266_638549447785828_7425451045707837861_n.jpg](attachment:305999266_638549447785828_7425451045707837861_n.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$\text{Tab.2.3: Kontigenčná tabuľka}$$

# %%
#1. spoôsob
library(tseries)
z<-factor(c("S","N","N","N","N","S","N","S","S","S","N","N"))
runs.test(z,alternative="less")
# Out:
# 	Runs Test
#
# data:  z
# Standard Normal = -0.52052, p-value = 0.3014
# alternative hypothesis: less

# %%
#2. spoôsob
library(randomizeBE)
pruns.exact(r=4,n1=7,n2=5,tail = "lower")
# Out:
# [1] 0.07575758

# %%
#3. spoôsob
#prvý riadok - prvý stĺpec, prvý riadok - druhý stĺpec
tbl<-matrix(c(2,3,2,4),byrow=T, nrow=2)
fisher.test(tbl,alternative = "greater")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  tbl
# p-value = 0.6515
# alternative hypothesis: true odds ratio is greater than 1
# 95 percent confidence interval:
#  0.09017168        Inf
# sample estimates:
# odds ratio
#   1.298679

# %% [markdown]
# Opäť nemôžeme zamietnuť $H_0$, pretože $p$-hodnota je väčšia než $\alpha$.

# %% [markdown]
# ### 3.PRÍKLAD
# Teraz si už zoberieme "dobrú hru" (nad 200 bodov)
# Máme výsledok $$S,N,S,S,S,N,N,N,S,S,S,S$$

# %% [markdown]
# ![306020872_497381338406319_2879119622962648465_n.jpg](attachment:306020872_497381338406319_2879119622962648465_n.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$\text{Tab.2.4: Kontigenčná tabuľka}$$

# %%
#1. spôsob
library(tseries)
y<-factor(c("S","N","S","S","S","N","N","N","S","S","S","S"))
runs.test(y,alternative="less")
# Out:
# 	Runs Test
#
# data:  y
# Standard Normal = -0.91987, p-value = 0.1788
# alternative hypothesis: less

# %%
#2. spôsob
library(randomizeBE)
pruns.exact(r=4,n1=8,n2=4,tail = "lower")
# Out:
# [1] 0.1090909

# %%
#3. spôsob
#prvý riadok - prvý stĺpec, prvý riadok - druhý stĺpec
tbl<-matrix(c(5,2,2,2),byrow=T, nrow=2)
fisher.test(tbl,alternative = "greater")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  tbl
# p-value = 0.4697
# alternative hypothesis: true odds ratio is greater than 1
# 95 percent confidence interval:
#  0.1505334       Inf
# sample estimates:
# odds ratio
#   2.288354

# %% [markdown]
# Opäť, kvôli vysokej hodnote $p$ nemôžeme zamietnuť $H_0$.

# %% [markdown]
# ### 4.PRÍKLAD
# Najlepšie skóre je **237** bodov.
# Máme výsledok $$N,S,N,N,N,S,S,S,S,S,S,S$$

# %% [markdown]
# ![305471767_1531388203956497_6291831432117842569_n.jpg](attachment:305471767_1531388203956497_6291831432117842569_n.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$\text{Tab.2.5: Kontigenčná tabuľka}$$

# %%
#1.spôsob
library(tseries)
x<-factor(c("N","S","N","N","N","S","S","S","S","S","S","S"))
runs.test(x,alternative="less")
# Out:
# 	Runs Test
#
# data:  x
# Standard Normal = -1.6098, p-value = 0.05372
# alternative hypothesis: less

# %%
#2.spôsob
library(randomizeBE)
pruns.exact(r=7,n1=8,n2=4,tail = "lower")
# Out:
# [1] 0.7878788

# %%
#3.spôsob
#prvý riadok - prvý stĺpec, prvý riadok - druhý stĺpec
tbl<-matrix(c(6,1,2,2),byrow=T, nrow=2)
fisher.test(tbl,alternative = "greater")
# Out:
# 	Fisher's Exact Test for Count Data
#
# data:  tbl
# p-value = 0.2788
# alternative hypothesis: true odds ratio is greater than 1
# 95 percent confidence interval:
#  0.2644498       Inf
# sample estimates:
# odds ratio
#   4.953797

# %% [markdown]
# Vyšlo opäť to isté, čo sme už intuitívne čakali. Nezamietame $H_0$.

# %% [markdown]
# ***
# <a id=Záver></a>
# # <font color=blueviolet>Záver</font>
#
#
# ### Zhodnotenie celej problematiky
# V tejto časti sme skúmali, či výsledky hráčov v priebehu hry sú na sebe nezávislé. Nezávislosť výsledkov berieme ako nulovú hypotézu $H_0$. Keďže sme vykonali viacero testov a ani jeden test nám nezamietol $H_0$ (čiže $p$-hodnota väčšia ako $\alpha$), tým pádom sme nepotvrdili závislosť výsledkov. V žiadnom prípade totiž nevyšla $p$-hodnota menšia ako $\alpha$.

# %% [markdown]
# ***
# <a id=Zdroje></a>
# # <font color=blueviolet>Zdroje</font>
#
#
# ### Zoznam použitej literatúry:
#
# * [Stránka o online hrách, športe a hudbe ...](https://slepolol.estranky.sk/clanky/Bowling.html)
#
#
# * Anděl, J. (2018). Statistické úlohy, historky a paradoxy. Matfyzpress.
#
#
# * Réalne dáta od konkrétneho hráča.
